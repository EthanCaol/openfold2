# %%
#!/usr/bin/env python3
import sys
import os

# 添加项目根目录到 Python 路径
sys.path.insert(0, os.getcwd())

print(f"Python 路径: {sys.path[:3]}...")

try:
    import openfold
    print(f"✅ 成功导入 openfold")
    print(f"   版本: {getattr(openfold, '__version__', '未指定')}")
    print(f"   位置: {openfold.__file__}")
    
    # 尝试导入子模块
    from openfold import model
    print(f"✅ 成功导入 openfold.model")
    
    from openfold.data import data_transforms
    print(f"✅ 成功导入 openfold.data.data_transforms")
    
except ImportError as e:
    print(f"❌ 导入失败: {e}")
    print("\n建议:")
    print("1. 确保在项目根目录运行")
    print("2. 或设置 PYTHONPATH=.")
    print("3. 或使用开发模式安装: pip install -e .")
# Out:
# Python 路径: ['/home/ethan/openfold2/tests', '/home/ethan/miniconda3/lib/python313.zip', '/home/ethan/miniconda3/lib/python3.13']...
# ✅ 成功导入 openfold
#    版本: 未指定
#    位置: /home/ethan/openfold2/openfold/__init__.py
# ✅ 成功导入 openfold.model
# ✅ 成功导入 openfold.data.data_transforms

# %%
# !export PYTHONPATH=~/openfold2:$PYTHONPATH
